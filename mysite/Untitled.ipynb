# %%
pwd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pwd()
#
# NameError: name 'pwd' is not defined

# %%
ls
# Out:
# Analisi_trade.csv    db.sqlite3           mysite/
# Untitled.ipynb       ib/                  portfolio.csv
# analisi.csv          index.html           scadenza.png
# analisi_perdite.csv  manage (copy).py*    trades.csv
# analisi_portafoglio/ manage.py*

# %%
import os

# %%
import pandas as pd

# %%
df1 = pd.read_csv("portfolio.csv")

# %%
print(df1)
# Out:
#        Strumento finanziario  Operazione ticker  Delta Valore temporale (%)  \
# 0   MSFT Sep15'23 327.5 CALL                NaN    NaN        1.26 (69.26%)
# 1      IWM Sep15'23 183 CALL                NaN    NaN        0.80 (79.38%)
# 2    AXP Sep15'23 157.5 CALL                NaN    NaN        0.63 (72.54%)
# 3      CVX Oct20'23 165 CALL                NaN    NaN        3.67 (21.69%)
# 4      MRK Oct20'23 110 CALL                NaN    NaN        2.07 (18.73%)
# 5      QQQ Sep15'23 374 CALL                NaN    NaN       2.35 (114.98%)
# 6      CVX Oct20'23 170 CALL                NaN  0.421        2.85 (16.85%)
# 7      JNJ Oct20'23 170 CALL                NaN  0.263         1.27 (7.66%)
# 8      SPY Sep15'23 449 CALL                NaN  0.245        0.89 (36.41%)
# 9      MRK Oct20'23 115 CALL                NaN  0.210         0.57 (5.16%)
# 10    AAPL Nov17'23 195 CALL                NaN  0.163         1.35 (4.30%)
# ...

# %%
df1.head()
# Out:
#       Strumento finanziario  Operazione ticker  Delta Valore temporale (%)  \
# 0  MSFT Sep15'23 327.5 CALL                NaN    NaN        1.26 (69.26%)
# 1     IWM Sep15'23 183 CALL                NaN    NaN        0.80 (79.38%)
# 2   AXP Sep15'23 157.5 CALL                NaN    NaN        0.63 (72.54%)
# 3     CVX Oct20'23 165 CALL                NaN    NaN        3.67 (21.69%)
# 4     MRK Oct20'23 110 CALL                NaN    NaN        2.07 (18.73%)
#
#    Posizione  Pr. medio Val mkt  P&L giorn.  P&L non realizzato Ultimo  \
# 0         -1      4.839    -565          -6                 -81  C5.59
# 1         -2      2.827    -442         -41                 123  C2.01
# 2         -2      2.843    -373         -13                 195  C1.80
# 3         -1      5.659    -557           5                   9  C5.62
# 4         -2      2.132    -417           4                  10  C2.11
#
#    Modifica  Variazione %  Gamma  Vega  Theta  Delta portafoglio  \
# ...
